# %%
import spacy
from collections import Counter
import gensim
from gensim import corpora
from gensim.models import Phrases

nlp = spacy.load("en_core_web_sm")

import nltk
from nltk.corpus import reuters #import reuters' documents from the nltk library

# %% [markdown]
# ### Preprocessing

# %%
def preprocess_text(text):
    # lowercasing
    doc = nlp(text.lower())
    
    # Initialize an empty list to hold the preprocessed tokens
    preprocessed_tokens = []
    
    # calculate the token frequency in the text
    token_counts = Counter([token.text for token in doc if token.is_alpha])

    # Preprocessing
    for token in doc: #for each token check 
        if (token.is_alpha and # to remove non-alphabetic caracters (punctuations, numbers ...),
            not token.is_stop and # to remove stopwords,
            token_counts[token.text] > 2 and # to remove rare words,
            token_counts[token.text] < 10):  # to remove frequent words,
            
            # Apply Lemmatization
            preprocessed_tokens.append(token.lemma_)
    
    return preprocessed_tokens

# %%
result = []
docs = []
fileids = reuters.fileids() #Get the documents ids
for i in range(100):
    docs = reuters.raw(fileids[i])
    result.append(preprocess_text(docs)) # Get the text of the first document

# %%
result
# Out:
# [['exporter',
#   'businessman',
#   'import',
#   'product',
#   'exporter',
#   'short',
#   'term',
#   'dlrs',
#   'tariff',
#   'import',
#   'japanese',
#   'electronic',
#   'semiconductor',
#   'japanese',
#   'tariff',
#   'billion',
#   'dlrs',
#   'electronic',
#   'export',
#   'product',
#   'japanese',
#   'electronics',
#   'tariff',
#   'export',
#   'tariff',
#   'taiwan',
#   'businessman',
#   'taiwan',
#   'surplus',
#   'billion',
#   'dlrs',
#   'year',
#   'surplus',
#   'taiwan',
#   'billion',
#   'dlrs',
#   'tariff',
#   'import',
#   'product',
#   'exporter',
#   'south',
#   'korea',
#   'south',
#   'korea',
#   'export',
#   'year',
#   'south',
#   'korea',
#   'surplus',
#   'billion',
#   'dlrs',
#   'billion',
#   'dlrs',
#   'businessman',
#   'semiconductor',
#   'hong',
#   'kong',
#   'semiconductor',
#   'electronic',
#   'businessman',
#   'short',
#   'term',
#   'import',
#   'short',
#   'term',
#   'hong',
#   'kong',
#   'industry',
#   'import',
#   'hong',
#   'kong',
#   'year',
#   'hong',
#   'kong',
#   'export',
#   'industry',
#   'minister',
#   'export',
#   'export',
#   'japanese',
#   'year',
#   'minister',
#   'minister',
#   'industry'],
#  ['china',
#   'pct',
#   'pct',
#   'china',
#   'china',
#   'say',
#   'say',
#   'pct',
#   'china',
#   'pct',
#   'say'],
#  ['energy',
#   'demand',
#   'miti',
#   'energy',
#   'supply',
#   'demand',
#   'energy',
#   'demand',
#   'say',
#   'miti',
#   'energy',
#   'say',
#   'demand',
#   'miti',
#   'energy',
#   'supply',
#   'demand',
#   'natural',
#   'energy',
#   'say',
#   'say',
#   'miti',
#   'energy',
#   'supply',
#   'natural',
#   'energy',
#   'pct',
#   'pct',
#   'natural',
#   'pct'],
#  ['quarter',
#   'billion',
#   'baht',
#   'quarter',
#   'billion',
#   'say',
#   'say',
#   'billion',
#   'baht',
#   'billion',
#   'quarter',
#   'say',
#   'quarter',
#   'billion',
#   'baht',
#   'billion'],
#  ['indonesia',
#   'cpo',
#   'indonesia',
#   'palm',
#   'oil',
#   'cpo',
#   'harahap',
#   'cpo',
#   'say',
#   'harahap',
#   'say',
#   'indonesia',
#   'palm',
#   'oil',
#   'indonesia',
#   'palm',
#   'oil',
#   'palm',
#   'oil',
#   'harahap',
#   'say',
#   'cpo'],
#  ['ban',
#   'nsw',
#   'port',
#   'nsw',
#   'ban',
#   'nsw',
#   'port',
#   'shipping',
#   'say',
#   'ban',
#   'port',
#   'say',
#   'port',
#   'port',
#   'say',
#   'nsw',
#   'port',
#   'nsw',
#   'shipping',
#   'say',
#   'port',
#   'port',
#   'say',
#   'say',
#   'shipping'],
#  ['commodity',
#   'commodity',
#   'start',
#   'trade',
#   'commodity',
#   'nainggolan',
#   'trading',
#   'palm',
#   'oil',
#   'trading',
#   'palm',
#   'oil',
#   'palm',
#   'oil',
#   'trade',
#   'coffee',
#   'rubber',
#   'nainggolan',
#   'rubber',
#   'trading',
#   'coffee',
#   'rubber',
#   'coffee',
#   'trade',
#   'trading',
#   'rubber',
#   'trade',
#   'rubber',
#   'rubber',
#   'nainggolan',
#   'start',
#   'trading',
#   'coffee',
#   'rubber',
#   'start',
#   'trading',
#   'rubber',
#   'trading',
#   'coffee'],
#  [],
#  ['gold', 'wmc', 'say', 'gold', 'wmc', 'wmc', 'say', 'say', 'gold'],
#  ['merger',
#   'ltd',
#   'merger',
#   'heiwa',
#   'sogo',
#   'financial',
#   'analyst',
#   'heiwa',
#   'sogo',
#   'komatsu',
#   'year',
#   'komatsu',
#   'merger',
#   'financial',
#   'analyst',
#   'pay',
#   'heiwa',
#   'sogo',
#   'merger',
#   'analyst',
#   'security',
#   'business',
#   'ltd',
#   'financial',
#   'security',
#   'business',
#   'pay',
#   'pct',
#   'time',
#   'business',
#   'komatsu',
#   'pay',
#   'time',
#   'year',
#   'komatsu',
#   'komatsu',
#   'security',
#   'business',
#   'security',
#   'komatsu',
#   'business',
#   'komatsu',
#   'security',
#   'security',
#   'business',
#   'securities',
#   'ltd',
#   'pct',
#   'komatsu',
#   'security',
#   'business',
#   'security',
#   'bank',
#   'bank',
#   'pct',
#   'komatsu',
#   'year',
#   'bank',
#   'business',
#   'analyst',
#   'time',
#   'merger',
#   'heiwa',
#   'sogo'],
#  ['subroto',
#   'pact',
#   'extension',
#   'subroto',
#   'extension',
#   'sixth',
#   'ita',
#   'say',
#   'pact',
#   'say',
#   'pact',
#   'subroto',
#   'say',
#   'extension',
#   'ita',
#   'extension',
#   'sixth',
#   'say',
#   'sixth',
#   'ita',
#   'extension'],
#  ['bundesbank',
#   'billion',
#   'mark',
#   'bundesbank',
#   'billion',
#   'mark',
#   'today',
#   'spokesman',
#   'say',
#   'bank',
#   'billion',
#   'mark',
#   'liquidity',
#   'today',
#   'billion',
#   'mark',
#   'market',
#   'today',
#   'bundesbank',
#   'billion',
#   'mark',
#   'market',
#   'today',
#   'bundesbank',
#   'spokesman',
#   'say',
#   'liquidity',
#   'bank',
#   'billion',
#   'mark',
#   'bundesbank',
#   'billion',
#   'mark',
#   'bundesbank',
#   'spokesman',
#   'billion',
#   'mark',
#   'billion',
#   'bank',
#   'liquidity',
#   'say',
#   'bundesbank',
#   'liquidity',
#   'market',
#   'market',
#   'market',
#   'bundesbank',
#   'say'],
#  ['bond',
#   'corp',
#   'mining',
#   'bond',
#   'corp',
#   'mining',
#   'development',
#   'corp',
#   'mining',
#   'statement',
#   'say',
#   'copper',
#   'say',
#   'copper',
#   'company',
#   'say',
#   'copper',
#   'say',
#   'bond',
#   'company',
#   'gold',
#   'say',
#   'bond',
#   'mining',
#   'company',
#   'gold',
#   'say',
#   'development',
#   'development',
#   'company',
#   'gold',
#   'corp',
#   'statement',
#   'say',
#   'bond',
#   'corp',
#   'statement',
#   'say',
#   'development'],
#  ['china',
#   'industrial',
#   'output',
#   'quarter',
#   'china',
#   'industrial',
#   'output',
#   'pct',
#   'quarter',
#   'say',
#   'say',
#   'pct',
#   'quarter',
#   'industrial',
#   'output',
#   'pct',
#   'quarter',
#   'say',
#   'china',
#   'industrial'],
#  ['ministry',
#   'open',
#   'farm',
#   'trade',
#   'agriculture',
#   'ministry',
#   'open',
#   'farm',
#   'product',
#   'market',
#   'farm',
#   'export',
#   'ministry',
#   'official',
#   'import',
#   'sale',
#   'official',
#   'large',
#   'farm',
#   'product',
#   'farm',
#   'import',
#   'market',
#   'agriculture',
#   'open',
#   'market',
#   'open',
#   'market',
#   'export',
#   'agriculture',
#   'market',
#   'beef',
#   'import',
#   'market',
#   'large',
#   'beef',
#   'export',
#   'beef',
#   'import',
#   'sale',
#   'japanese',
#   'import',
#   'large',
#   'sale',
#   'beef',
#   'import',
#   'import',
#   'japanese',
#   'agriculture',
#   'large',
#   'export',
#   'beef',
#   'market',
#   'trade',
#   'japanese',
#   'import',
#   'farm',
#   'product',
#   'beef',
#   'product',
#   'trade',
#   'import',
#   'product',
#   'agriculture',
#   'ministry',
#   'official',
#   'farm',
#   'trade',
#   'large',
#   'farm',
#   'product',
#   'official'],
#  ['amatil',
#   'issue',
#   'amatil',
#   'say',
#   'issue',
#   'issue',
#   'say',
#   'amatil',
#   'say'],
#  ['profit', 'profit', 'profit', 'debit', 'debit', 'debit', 'debit'],
#  ['market',
#   'mln',
#   'stg',
#   'mln',
#   'stg',
#   'market',
#   'bill',
#   'bill',
#   'mln',
#   'stg',
#   'bill',
#   'market',
#   'mln',
#   'mln',
#   'stg',
#   'mln',
#   'stg'],
#  ['south',
#   'korea',
#   'growth',
#   'trade',
#   'south',
#   'korea',
#   'trade',
#   'government',
#   'kim',
#   'government',
#   'foreign',
#   'hold',
#   'government',
#   'south',
#   'korea',
#   'south',
#   'korea',
#   'trade',
#   'rise',
#   'billion',
#   'dlrs',
#   'billion',
#   'dlrs',
#   'kim',
#   'south',
#   'government',
#   'hold',
#   'current',
#   'account',
#   'billion',
#   'dlrs',
#   'year',
#   'government',
#   'pct',
#   'growth',
#   'billion',
#   'dlrs',
#   'current',
#   'account',
#   'pct',
#   'growth',
#   'year',
#   'trade',
#   'south',
#   'korea',
#   'rise',
#   'pct',
#   'billion',
#   'dlrs',
#   'year',
#   'rise',
#   'pct',
#   'billion',
#   'dlrs',
#   'kim',
#   'south',
#   'korea',
#   'current',
#   'account',
#   'billion',
#   'dlrs',
#   'reduce',
#   'foreign',
#   'debt',
#   'year',
#   'south',
#   'korea',
#   'foreign',
#   'debt',
#   'billion',
#   'dlrs',
#   'billion',
#   'foreign',
#   'debt',
#   'major',
#   'year',
#   'major',
#   'kim',
#   'kim',
#   'government',
#   'reduce',
#   'foreign',
#   'debt',
#   'pct',
#   'pct',
#   'government',
#   'debt',
#   'trade',
#   'kim',
#   'trade',
#   'major',
#   'reduce',
#   'debt',
#   'hold',
#   'kim'],
#  ['study',
#   'mtbe',
#   'plant',
#   'neste',
#   'oy',
#   'say',
#   'statement',
#   'canadian',
#   'study',
#   'plant',
#   'edmonton',
#   'canada',
#   'lead',
#   'plant',
#   'canadian',
#   'mtbe',
#   'say',
#   'study',
#   'neste',
#   'oy',
#   'celanese',
#   'canada',
#   'celanese',
#   'edmonton',
#   'celanese',
#   'canada',
#   'statement',
#   'say',
#   'plant',
#   'mtbe',
#   'lead',
#   'mtbe',
#   'lead',
#   'statement',
#   'canadian',
#   'lead',
#   'lead',
#   'canada',
#   'canadian',
#   'mtbe',
#   'say',
#   'neste',
#   'oy',
#   'mtbe',
#   'mtbe',
#   'plant',
#   'edmonton',
#   'plant',
#   'statement',
#   'say'],
#  ['cra',
#   'gold',
#   'whim',
#   'creek',
#   'creek',
#   'nl',
#   'cra',
#   'gold',
#   'cra',
#   'whim',
#   'creek',
#   'whim',
#   'creek',
#   'pct',
#   'nl',
#   'pct',
#   'nl',
#   'pct',
#   'gold',
#   'gold',
#   'gold'],
#  ['worker', 'worker', 'worker'],
#  ['bowater',
#   'profit',
#   'bowater',
#   'stg',
#   'bowater',
#   'stg',
#   'profit',
#   'bowater',
#   'stg',
#   'stg',
#   'profit',
#   'pct',
#   'profit',
#   'pct',
#   'pct'],
#  ['citibank',
#   'norway',
#   'crown',
#   'citibank',
#   'bank',
#   'say',
#   'crown',
#   'foreign',
#   'say',
#   'citibank',
#   'citibank',
#   'foreign',
#   'bank',
#   'norway',
#   'banking',
#   'banking',
#   'norway',
#   'year',
#   'foreign',
#   'norway',
#   'foreign',
#   'banking',
#   'say',
#   'norway',
#   'year',
#   'citibank',
#   'crown',
#   'norway',
#   'say',
#   'year',
#   'year',
#   'bank',
#   'foreign',
#   'banking'],
#  ['vieille',
#   'montagne',
#   'vieille',
#   'montagne',
#   'vieille',
#   'montagne',
#   'mln',
#   'mln',
#   'mln'],
#  ['exceptional',
#   'mln',
#   'franc',
#   'vs',
#   'mln',
#   'exceptional',
#   'mln',
#   'franc',
#   'vs',
#   'exceptional',
#   'mln',
#   'franc',
#   'vs',
#   'vs',
#   'franc'],
#  ['ec',
#   'tin',
#   'extension',
#   'ec',
#   'international',
#   'tin',
#   'say',
#   'extension',
#   'international',
#   'tin',
#   'ec',
#   'say',
#   'say',
#   'ec',
#   'say',
#   'ec',
#   'extension',
#   'international',
#   'tin',
#   'ec'],
#  ['japan',
#   'say',
#   'japan',
#   'trade',
#   'japan',
#   'say',
#   'say',
#   'japan',
#   'reduce',
#   'trade',
#   'trade',
#   'say',
#   'reduce',
#   'trade',
#   'reduce',
#   'say'],
#  ['zinc',
#   'march',
#   'zinc',
#   'tonne',
#   'march',
#   'march',
#   'tonne',
#   'tonne',
#   'tonne',
#   'zinc'],
#  ['sugar',
#   'european',
#   'sugar',
#   'tonne',
#   'european',
#   'tonne',
#   'european',
#   'tonne',
#   'sugar'],
#  [],
#  ['anheuser',
#   'busch',
#   'bid',
#   'san',
#   'miguel',
#   'anheuser',
#   'busch',
#   'share',
#   'san',
#   'miguel',
#   'corp',
#   'government',
#   'share',
#   'tell',
#   'diaz',
#   'government',
#   'say',
#   'anheuser',
#   'busch',
#   'tell',
#   'government',
#   'mln',
#   'b',
#   'share',
#   'san',
#   'miguel',
#   'diaz',
#   'say',
#   'australian',
#   'corp',
#   'ltd',
#   'b',
#   'share',
#   'diaz',
#   'say',
#   'say',
#   'mln',
#   'share',
#   'tell',
#   'ltd',
#   'bid',
#   'b',
#   'share',
#   'australian',
#   'ltd',
#   'ltd',
#   'australian',
#   'ltd',
#   'mln',
#   'share',
#   'anheuser',
#   'busch',
#   'mln',
#   'bid',
#   'miguel',
#   'ltd',
#   'corp',
#   'ltd',
#   'san',
#   'miguel',
#   'corp',
#   'say'],
#  ['economic',
#   'australian',
#   'market',
#   'boom',
#   'australian',
#   'market',
#   'boom',
#   'fund',
#   'manager',
#   'capital',
#   'united',
#   'states',
#   'market',
#   'analyst',
#   'high',
#   'interest',
#   'rate',
#   'market',
#   'currency',
#   'inflow',
#   'japanese',
#   'investor',
#   'analyst',
#   'fund',
#   'manager',
#   'market',
#   'australia',
#   'dollar',
#   'rate',
#   'record',
#   'high',
#   'currency',
#   'inflow',
#   'inflow',
#   'investment',
#   'capital',
#   'united',
#   'states',
#   'people',
#   'high',
#   'interest',
#   'rate',
#   'currency',
#   'australia',
#   'bank',
#   'australia',
#   'economic',
#   'money',
#   'australian',
#   'dollar',
#   'investor',
#   'currency',
#   'analyst',
#   'market',
#   'people',
#   'dollar',
#   'bank',
#   'buttrose',
#   'money',
#   'australia',
#   'currency',
#   'capital',
#   'investment',
#   'economic',
#   'policy',
#   'people',
#   'buttrose',
#   'offshore',
#   'investor',
#   'tough',
#   'economic',
#   'interest',
#   'fund',
#   'manager',
#   'particularly',
#   'japanese',
#   'australian',
#   'dollar',
#   'rate',
#   'analyst',
#   'money',
#   'tough',
#   'buttrose',
#   'offshore',
#   'investor',
#   'australia',
#   'tough',
#   'economic',
#   'analyst',
#   'money',
#   'buttrose',
#   'reserve',
#   'bank',
#   'policy',
#   'interest',
#   'investment',
#   'australia',
#   'japanese',
#   'investor',
#   'currency',
#   'reserve',
#   'yen',
#   'currency',
#   'policy',
#   'yen',
#   'japanese',
#   'investor',
#   'analyst',
#   'reserve',
#   'bank',
#   'recent',
#   'australian',
#   'dollar',
#   'yen',
#   'dollar',
#   'australian',
#   'dollar',
#   'offshore',
#   'booming',
#   'australian',
#   'market',
#   'market',
#   'offshore',
#   'particularly',
#   'record',
#   'record',
#   'japanese',
#   'united',
#   'states',
#   'recent',
#   'particularly',
#   'analyst',
#   'recent',
#   'japanese',
#   'capital',
#   'investment',
#   'investment',
#   'australia',
#   'buttrose'],
#  ['economic',
#   'economy',
#   'kuwait',
#   'debt',
#   'economy',
#   'price',
#   'opec',
#   'price',
#   'new',
#   'dlrs',
#   'economy',
#   'pct',
#   'year',
#   'pct',
#   'year',
#   'price',
#   'pct',
#   'pct',
#   'economic',
#   'year',
#   'kuwait',
#   'debt',
#   'new',
#   'debt',
#   'billion',
#   'dlrs',
#   'spending',
#   'credit',
#   'debt',
#   'billion',
#   'dinar',
#   'billion',
#   'dlrs',
#   'credit',
#   'debt',
#   'government',
#   'say',
#   'new',
#   'debt',
#   'credit',
#   'year',
#   'government',
#   'kuwait',
#   'opec',
#   'kuwait',
#   'opec',
#   'year',
#   'al',
#   'al',
#   'year',
#   'kuwait',
#   'dlrs',
#   'price',
#   'year',
#   'government',
#   'spending',
#   'billion',
#   'pct',
#   'kuwait',
#   'reserve',
#   'billion',
#   'dlrs',
#   'billion',
#   'dlrs',
#   'year',
#   'reserve',
#   'budget',
#   'year',
#   'budget',
#   'pct',
#   'spend',
#   'pct',
#   'billion',
#   'dinar',
#   'reserve',
#   'budget',
#   'billion',
#   'dinar',
#   'economic',
#   'year',
#   'price',
#   'say',
#   'al',
#   'say',
#   'spending',
#   'economy',
#   'budget'],
#  ['malaysia',
#   'palm',
#   'malaysia',
#   'output',
#   'mln',
#   'tonne',
#   'palm',
#   'palm',
#   'grower',
#   'output',
#   'expect',
#   'mln',
#   'tonne',
#   'say',
#   'grower',
#   'malaysia',
#   'palm',
#   'output',
#   'likely',
#   'palm',
#   'soybean',
#   'malaysia',
#   'palm',
#   'palm',
#   'tonne',
#   'grower',
#   'say',
#   'grower',
#   'palm',
#   'soybean',
#   'output',
#   'soybean',
#   'likely',
#   'mln',
#   'tonne',
#   'mln',
#   'say',
#   'new',
#   'soybean',
#   'expect',
#   'palm',
#   'output',
#   'say',
#   'new',
#   'likely',
#   'expect',
#   'new'],
#  [],
#  ['monier',
#   'redland',
#   'monier',
#   'say',
#   'redland',
#   'moni',
#   'share',
#   'say',
#   'redland',
#   'monier',
#   'mln',
#   'share',
#   'say',
#   'say',
#   'share',
#   'moni',
#   'share',
#   'dlrs',
#   'dlrs',
#   'monier',
#   'mln',
#   'dlrs',
#   'mln'],
#  ['dividend',
#   'dividend',
#   'half',
#   'company',
#   'yen',
#   'company',
#   'half',
#   'yen',
#   'company',
#   'company',
#   'dividend',
#   'yen',
#   'yen',
#   'half'],
#  ['japanese',
#   'datum',
#   'talk',
#   'trade',
#   'kuroda',
#   'datum',
#   'trade',
#   'japanese',
#   'trade',
#   'talk',
#   'kuroda',
#   'trade',
#   'japanese',
#   'kuroda',
#   'say',
#   'kuroda',
#   'kuroda',
#   'say',
#   'datum',
#   'say',
#   'kuroda',
#   'say',
#   'talk',
#   'talk',
#   'trade',
#   'say',
#   'talk'],
#  ['bell',
#   'standard',
#   'bell',
#   'standard',
#   'bell',
#   'bell',
#   'standard',
#   'bell',
#   'standard'],
#  ['nippon',
#   'steel',
#   'china',
#   'japanese',
#   'nippon',
#   'steel',
#   'china',
#   'steel',
#   'japanese',
#   'nippon',
#   'steel',
#   'china',
#   'japanese',
#   'steel',
#   'nippon',
#   'steel',
#   'china',
#   'nippon',
#   'steel',
#   'china',
#   'china',
#   'steel',
#   'steel'],
#  ['jardine',
#   'matheson',
#   'b',
#   'share',
#   'bonus',
#   'issue',
#   'jardine',
#   'matheson',
#   'say',
#   'bonus',
#   'issue',
#   'b',
#   'share',
#   'bonus',
#   'issue',
#   'share',
#   'say',
#   'share',
#   'jardine',
#   'matheson',
#   'issue',
#   'b',
#   'share',
#   'say',
#   'jardine',
#   'matheson',
#   'jardine',
#   'b',
#   'share',
#   'shareholder',
#   'say',
#   'b',
#   'share',
#   'issue',
#   'jardine',
#   'matheson',
#   'shareholder',
#   'issue',
#   'share',
#   'shareholder'],
#  ['japan',
#   'say',
#   'japan',
#   'trade',
#   'japan',
#   'say',
#   'say',
#   'japan',
#   'reduce',
#   'trade',
#   'trade',
#   'say',
#   'reduce',
#   'trade',
#   'reduce',
#   'say'],
#  ['bank', 'bank', 'yen', 'bank', 'dollar', 'dollar', 'yen', 'dollar', 'yen'],
#  ['pct', 'pct', 'pct'],
#  ['mln',
#   'stg',
#   'bank',
#   'mln',
#   'stg',
#   'bank',
#   'mln',
#   'stg',
#   'mln',
#   'bank',
#   'bank',
#   'mln',
#   'stg',
#   'mln',
#   'stg'],
#  ['san',
#   'miguel',
#   'san',
#   'miguel',
#   'corp',
#   'mln',
#   'sequester',
#   'ucpb',
#   'source',
#   'company',
#   'ucpb',
#   'pct',
#   'mln',
#   'april',
#   'petition',
#   'file',
#   'eduardo',
#   'cojuangco',
#   'ucpb',
#   'cojuangco',
#   'mln',
#   'cojuangco',
#   'ucpb',
#   'petition',
#   'ucpb',
#   'source',
#   'share',
#   'suit',
#   'file',
#   'sec',
#   'eduardo',
#   'de',
#   'los',
#   'angeles',
#   'government',
#   'company',
#   'board',
#   'de',
#   'los',
#   'angeles',
#   'sec',
#   'company',
#   'board',
#   'april',
#   'board',
#   'sequester',
#   'billion',
#   'peso',
#   'pesos',
#   'share',
#   'de',
#   'los',
#   'angeles',
#   'sec',
#   'company',
#   'billion',
#   'peso',
#   'de',
#   'los',
#   'angeles',
#   'share',
#   'board',
#   'sec',
#   'de',
#   'los',
#   'angeles',
#   'suit',
#   'soriano',
#   'de',
#   'los',
#   'angeles',
#   'mln',
#   'corp',
#   'board',
#   'april',
#   'suit',
#   'file',
#   'eduardo',
#   'de',
#   'los',
#   'angeles',
#   'sequester',
#   'san',
#   'miguel',
#   'corp',
#   'statement',
#   'san',
#   'miguel',
#   'corp',
#   'ucpb',
#   'suit',
#   'government',
#   'april',
#   'statement',
#   'san',
#   'miguel',
#   'cojuangco',
#   'petition',
#   'statement',
#   'diaz',
#   'government',
#   'sequester',
#   'soriano',
#   'sequester',
#   'mln',
#   'mln',
#   'buyer',
#   'source',
#   'soriano',
#   'buyer',
#   'soriano',
#   'buyer',
#   'mln',
#   'ucpb',
#   'diaz',
#   'government',
#   'sequester',
#   'cojuangco',
#   'cojuangco',
#   'mln',
#   'pct',
#   'soriano',
#   'diaz',
#   'company',
#   'san',
#   'miguel',
#   'corp',
#   'billion',
#   'pesos',
#   'pct',
#   'billion',
#   'mln',
#   'pesos',
#   'pct'],
#  ['queensland',
#   'sugar',
#   'cane',
#   'crop',
#   'sugar',
#   'cane',
#   'crop',
#   'region',
#   'queensland',
#   'sugar',
#   'spokesman',
#   'say',
#   'region',
#   'crop',
#   'spokesman',
#   'say',
#   'crop',
#   'cane',
#   'spokesman',
#   'say',
#   'queensland',
#   'region',
#   'queensland',
#   'cane',
#   'crop',
#   'say',
#   'crop',
#   'say',
#   'cane'],
#  ['trader',
#   'sugar',
#   'tender',
#   'award',
#   'tender',
#   'tonne',
#   'sugar',
#   'week',
#   'award',
#   'tonne',
#   'trader',
#   'say',
#   'week',
#   'trader',
#   'say',
#   'tender',
#   'week',
#   'award',
#   'tonne',
#   'sugar',
#   'say'],
#  ['fondiaria',
#   'fondiaria',
#   'billion',
#   'lira',
#   'billion',
#   'lira',
#   'billion',
#   'lira',
#   'billion',
#   'fondiaria'],
#  ['nickel',
#   'price',
#   'shearson',
#   'nickel',
#   'price',
#   'shearson',
#   'nickel',
#   'market',
#   'market',
#   'dlrs',
#   'lb',
#   'year',
#   'dlrs',
#   'nickel',
#   'shearson',
#   'year',
#   'year',
#   'shearson',
#   'nickel',
#   'market',
#   'tonne',
#   'tonne',
#   'tonne',
#   'tonne',
#   'price',
#   'year',
#   'average',
#   'dlrs',
#   'lb',
#   'dlrs',
#   'year',
#   'average',
#   'dlrs',
#   'lb',
#   'dlrs',
#   'price',
#   'average',
#   'dlrs'],
#  ['dutch',
#   'firm',
#   'dsm',
#   'dutch',
#   'firm',
#   'dsm',
#   'say',
#   'mln',
#   'guilde',
#   'mln',
#   'guilde',
#   'say',
#   'dutch',
#   'firm',
#   'mln',
#   'guilde',
#   'mln',
#   'guilde',
#   'dsm',
#   'say'],
#  ['poehl',
#   'dollar',
#   'poehl',
#   'dollar',
#   'mark',
#   'west',
#   'german',
#   'growth',
#   'german',
#   'poehl',
#   'policy',
#   'dollar',
#   'trade',
#   'inflation',
#   'poehl',
#   'west',
#   'germany',
#   'rate',
#   'money',
#   'supply',
#   'growth',
#   'year',
#   'west',
#   'german',
#   'west',
#   'germany',
#   'mark',
#   'poehl',
#   'west',
#   'germany',
#   'mark',
#   'growth',
#   'poehl',
#   'money',
#   'supply',
#   'growth',
#   'year',
#   'inflation',
#   'trade',
#   'poehl',
#   'west',
#   'germany',
#   'policy',
#   'inflation',
#   'inflation',
#   'rate',
#   'year',
#   'west',
#   'germany',
#   'policy',
#   'money',
#   'supply',
#   'trade',
#   'poehl',
#   'rate',
#   'dollar',
#   'growth',
#   'dollar'],
#  ['auxton', 'auxton', 'auxton', 'auxton'],
#  ['california',
#   'california',
#   'say',
#   'dlrs',
#   'dlrs',
#   'quarter',
#   'company',
#   'say',
#   'year',
#   'say',
#   'quarter',
#   'quarter',
#   'company',
#   'dlrs',
#   'company',
#   'year',
#   'year',
#   'year',
#   'quarter',
#   'year',
#   'california',
#   'dlrs'],
#  [],
#  ['unilever',
#   'stauffer',
#   'unilever',
#   'unilever',
#   'unilever',
#   'stauffer',
#   'chesebrough',
#   'stauffer',
#   'unilever',
#   'stauffer',
#   'chesebrough',
#   'stauffer',
#   'unilever',
#   'chesebrough'],
#  [],
#  ['conrac',
#   'conrac',
#   'conrac',
#   'dlrs',
#   'conrac',
#   'conrac',
#   'mln',
#   'dlrs',
#   'dlrs',
#   'mln',
#   'dlrs',
#   'mln'],
#  ['ldp',
#   'ldp',
#   'product',
#   'ldp',
#   'product',
#   'product',
#   'product',
#   'ldp',
#   'ldp'],
#  ['net',
#   'ct',
#   'vs',
#   'ct',
#   'net',
#   'vs',
#   'vs',
#   'ct',
#   'vs',
#   'ct',
#   'net',
#   'vs',
#   'vs'],
#  ['ban',
#   'nsw',
#   'ban',
#   'nsw',
#   'port',
#   'say',
#   'ban',
#   'say',
#   'port',
#   'say',
#   'nsw',
#   'port',
#   'nsw'],
#  ['ct', 'ct', 'ct', 'ct'],
#  ['dispute',
#   'port',
#   'dispute',
#   'employer',
#   'say',
#   'employer',
#   'redundancy',
#   'sector',
#   'employer',
#   'redundancy',
#   'port',
#   'union',
#   'redundancy',
#   'say',
#   'employer',
#   'dispute',
#   'port',
#   'sector',
#   'sector',
#   'say',
#   'employer',
#   'union',
#   'union'],
#  ['net',
#   'ct',
#   'vs',
#   'ct',
#   'net',
#   'vs',
#   'mln',
#   'vs',
#   'mln',
#   'vs',
#   'ct',
#   'vs',
#   'net',
#   'vs',
#   'mln',
#   'vs',
#   'mln',
#   'vs'],
#  ['vs', 'mln', 'vs', 'mln', 'mln', 'vs', 'mln'],
#  ['net',
#   'profit',
#   'ct',
#   'vs',
#   'loss',
#   'ct',
#   'net',
#   'profit',
#   'vs',
#   'loss',
#   'mln',
#   'vs',
#   'mln',
#   'profit',
#   'ct',
#   'vs',
#   'loss',
#   'ct',
#   'net',
#   'profit',
#   'vs',
#   'loss',
#   'mln',
#   'vs',
#   'mln'],
#  ['mln',
#   'stg',
#   'bank',
#   'mln',
#   'stg',
#   'band',
#   'buy',
#   'mln',
#   'stg',
#   'bill',
#   'mln',
#   'stg',
#   'bank',
#   'bill',
#   'pct',
#   'band',
#   'buy',
#   'mln',
#   'stg',
#   'bank',
#   'bill',
#   'pct',
#   'buy',
#   'mln',
#   'stg',
#   'band',
#   'bank',
#   'bill',
#   'pct',
#   'bank',
#   'mln',
#   'stg',
#   'mln',
#   'stg'],
#  [],
#  ['mln', 'dlrs', 'mln', 'dlrs', 'mln', 'dlrs', 'mln', 'dlrs'],
#  ['vs', 'vs', 'vs'],
#  ['net', 'vs', 'net', 'vs', 'net', 'dlrs', 'vs', 'dlrs', 'dlrs', 'vs', 'dlrs'],
#  ['vs', 'vs', 'vs', 'vs'],
#  ['net',
#   'ct',
#   'vs',
#   'ct',
#   'net',
#   'vs',
#   'vs',
#   'ct',
#   'vs',
#   'ct',
#   'net',
#   'vs',
#   'vs'],
#  ['march', 'march', 'march'],
#  ['compaq',
#   'expect',
#   'quarter',
#   'compaq',
#   'say',
#   'expect',
#   'sale',
#   'earning',
#   'quarter',
#   'analyst',
#   'demand',
#   'compaq',
#   'say',
#   'expect',
#   'sale',
#   'mln',
#   'dlrs',
#   'analyst',
#   'mln',
#   'dlrs',
#   'earning',
#   'share',
#   'analyst',
#   'share',
#   'compaq',
#   'earning',
#   'mln',
#   'dlrs',
#   'share',
#   'sale',
#   'mln',
#   'dlrs',
#   'quarter',
#   'say',
#   'demand',
#   'deskpro',
#   'compaq',
#   'deskpro',
#   'sale',
#   'demand',
#   'compaq',
#   'compaq',
#   'deskpro',
#   'compaq',
#   'say',
#   'demand',
#   'quarter'],
#  ['international',
#   'international',
#   'say',
#   'hawaiian',
#   'hawaiian',
#   'say',
#   'international',
#   'say',
#   'hawaiian',
#   'say'],
#  ['net',
#   'nil',
#   'vs',
#   'nil',
#   'net',
#   'vs',
#   'vs',
#   'vs',
#   'nil',
#   'net',
#   'vs',
#   'vs'],
#  ['legislation',
#   'legislation',
#   'takeover',
#   'shareholder',
#   'stock',
#   'act',
#   'legislation',
#   'shareholder',
#   'takeover',
#   'bill',
#   'stock',
#   'pct',
#   'current',
#   'pct',
#   'day',
#   'requirement',
#   'pct',
#   'requirement',
#   'takeover',
#   'tender',
#   'act',
#   'day',
#   'current',
#   'day',
#   'bill',
#   'tender',
#   'takeover',
#   'legislation',
#   'current',
#   'margin',
#   'pct',
#   'margin',
#   'requirement',
#   'stock',
#   'takeover',
#   'takeover',
#   'takeover',
#   'bill',
#   'pct',
#   'margin',
#   'bill',
#   'takeover',
#   'tender',
#   'shareholder',
#   'bill',
#   'bill',
#   'act',
#   'bill'],
#  ['net',
#   'ct',
#   'vs',
#   'ct',
#   'net',
#   'vs',
#   'mln',
#   'vs',
#   'vs',
#   'vs',
#   'ct',
#   'net',
#   'vs',
#   'mln',
#   'vs',
#   'mln',
#   'vs',
#   'net'],
#  ['bankers',
#   'trust',
#   'brazil',
#   'banker',
#   'trust',
#   'say',
#   'mln',
#   'dlrs',
#   'term',
#   'brazil',
#   'mln',
#   'dlrs',
#   'brazil',
#   'interest',
#   'payment',
#   'dlrs',
#   'term',
#   'debt',
#   'interest',
#   'payment',
#   'bankers',
#   'trust',
#   'say',
#   'payment',
#   'interest',
#   'banker',
#   'trust',
#   'mln',
#   'dlrs',
#   'bankers',
#   'trust',
#   'say',
#   'debt',
#   'brazil',
#   'interest',
#   'payment',
#   'dlrs',
#   'term',
#   'debt'],
#  ['vs', 'vs', 'vs'],
#  [],
#  ['stoltenberg',
#   'paris',
#   'accord',
#   'west',
#   'german',
#   'stoltenberg',
#   'say',
#   'major',
#   'country',
#   'paris',
#   'accord',
#   'stoltenberg',
#   'agreement',
#   'country',
#   'stoltenberg',
#   'poehl',
#   'say',
#   'paris',
#   'agreement',
#   'louvre',
#   'accord',
#   'stoltenberg',
#   'say',
#   'agreement',
#   'major',
#   'country',
#   'major',
#   'paris',
#   'accord',
#   'say',
#   'stoltenberg',
#   'say',
#   'louvre',
#   'agreement',
#   'dollar',
#   'poehl',
#   'dollar',
#   'dollar',
#   'louvre',
#   'agreement',
#   'say',
#   'poehl',
#   'say',
#   'west',
#   'paris',
#   'poehl',
#   'say',
#   'paris',
#   'stoltenberg',
#   'west',
#   'german',
#   'dollar',
#   'dollar',
#   'german',
#   'say'],
#  ['tonne',
#   'export',
#   'european',
#   'european',
#   'trader',
#   'tonne',
#   'tonne',
#   'trader',
#   'tonne',
#   'trader',
#   'tonne',
#   'export',
#   'tonne',
#   'tonne',
#   'export',
#   'european'],
#  ['mead',
#   'improved',
#   'earning',
#   'year',
#   'mead',
#   'say',
#   'strong',
#   'quarter',
#   'earning',
#   'strong',
#   'improve',
#   'earning',
#   'year',
#   'say',
#   'quarter',
#   'earning',
#   'mln',
#   'dlrs',
#   'dlrs',
#   'share',
#   'mln',
#   'dlrs',
#   'share',
#   'year',
#   'quarter',
#   'earning',
#   'operation',
#   'mln',
#   'dlrs',
#   'dlrs',
#   'share',
#   'mead',
#   'say',
#   'quarter',
#   'improved',
#   'operation',
#   'operation',
#   'say',
#   'mead',
#   'improve',
#   'strong',
#   'year',
#   'mead',
#   'say',
#   'strong',
#   'quarter'],
#  ['vs', 'vs', 'vs'],
#  ['ct', 'vs', 'ct', 'ct', 'vs', 'ct', 'ct', 'vs', 'ct', 'vs', 'vs'],
#  ['vs', 'vs', 'mln', 'vs', 'mln', 'vs', 'vs', 'vs', 'mln', 'vs', 'mln', 'vs'],
#  ['paxar', 'paxar', 'paxar'],
#  ['vs', 'vs', 'vs'],
#  ['canadian',
#   'bashaw',
#   'erskine',
#   'canadian',
#   'bashaw',
#   'erskine',
#   'canadian',
#   'bashaw',
#   'erskine'],
#  ['entourage',
#   'entourage',
#   'say',
#   'dlrs',
#   'dlrs',
#   'dlrs',
#   'company',
#   'entourage',
#   'say',
#   'dlrs',
#   'company',
#   'say',
#   'company'],
#  ['vs', 'vs', 'vs'],
#  ['ct', 'ct', 'ct', 'ct'],
#  [],
#  ['sugar',
#   'beet',
#   'year',
#   'expect',
#   'sugar',
#   'beet',
#   'crop',
#   'sugar',
#   'crop',
#   'expect',
#   'april',
#   'april',
#   'year',
#   'year',
#   'april',
#   'crop',
#   'year',
#   'record',
#   'sugar',
#   'beet',
#   'record',
#   'tonne',
#   'sugar',
#   'quota',
#   'tonne',
#   'year',
#   'quota',
#   'sugar',
#   'tonne',
#   'quota',
#   'sugar',
#   'record',
#   'beet',
#   'expect',
#   'sugar'],
#  ['dlrs', 'dlrs', 'dlrs', 'dlrs'],
#  ['tonne', 'tonne', 'tonne'],
#  ['dividend',
#   'tomorrow',
#   'vw',
#   'dividend',
#   'tomorrow',
#   'mark',
#   'currency',
#   'say',
#   'vw',
#   'supervisory',
#   'board',
#   'tomorrow',
#   'vw',
#   'say',
#   'mark',
#   'currency',
#   'company',
#   'vw',
#   'currency',
#   'say',
#   'board',
#   'dividend',
#   'supervisory',
#   'board',
#   'dividend',
#   'mark',
#   'company',
#   'say',
#   'supervisory',
#   'board',
#   'board',
#   'say',
#   'company',
#   'say',
#   'vw',
#   'company',
#   'mark']]

# %% [markdown]
# ### Bag of Words

# %%
dictionary = corpora.Dictionary(result)
print(dictionary.token2id)
corpus = [dictionary.doc2bow(text) for text in result]
print(corpus)
# Out:
# {'billion': 0, 'businessman': 1, 'dlrs': 2, 'electronic': 3, 'electronics': 4, 'export': 5, 'exporter': 6, 'hong': 7, 'import': 8, 'industry': 9, 'japanese': 10, 'kong': 11, 'korea': 12, 'minister': 13, 'product': 14, 'semiconductor': 15, 'short': 16, 'south': 17, 'surplus': 18, 'taiwan': 19, 'tariff': 20, 'term': 21, 'year': 22, 'china': 23, 'pct': 24, 'say': 25, 'demand': 26, 'energy': 27, 'miti': 28, 'natural': 29, 'supply': 30, 'baht': 31, 'quarter': 32, 'cpo': 33, 'harahap': 34, 'indonesia': 35, 'oil': 36, 'palm': 37}
# [[(0, 5), (1, 4), (2, 6), (3, 3), (4, 1), (5, 6), (6, 3), (7, 4), (8, 5), (9, 3), (10, 4), (11, 4), (12, 3), (13, 3), (14, 3), (15, 3), (16, 3), (17, 3), (18, 3), (19, 3), (20, 5), (21, 3), (22, 4)], [(23, 4), (24, 4), (25, 3)], [(24, 3), (25, 4), (26, 5), (27, 8), (28, 4), (29, 3), (30, 3)], [(0, 6), (25, 3), (31, 3), (32, 4)], [(25, 3), (33, 4), (34, 3), (35, 4), (36, 4), (37, 4)]]

# %% [markdown]
# ### TD-IDF

# %%
#TF-IDF
from gensim import models
tfidf = models.TfidfModel(corpus)
for document in tfidf[corpus]:
    print(document)
# Out:
# [(0, 0.15935418401749438), (1, 0.2239207765318571), (2, 0.3358811647977857), (3, 0.16794058239889284), (4, 0.055980194132964275), (5, 0.3358811647977857), (6, 0.16794058239889284), (7, 0.2239207765318571), (8, 0.2799009706648214), (9, 0.16794058239889284), (10, 0.2239207765318571), (11, 0.2239207765318571), (12, 0.16794058239889284), (13, 0.16794058239889284), (14, 0.16794058239889284), (15, 0.16794058239889284), (16, 0.16794058239889284), (17, 0.16794058239889284), (18, 0.16794058239889284), (19, 0.16794058239889284), (20, 0.2799009706648214), (21, 0.16794058239889284), (22, 0.2239207765318571)]
# [(23, 0.8655034152183875), (24, 0.4927513833513657), (25, 0.08999951361325781)]
# [(24, 0.1520225789906905), (25, 0.04936258325861676), (26, 0.4450387008956973), (27, 0.7120619214331158), (28, 0.3560309607165579), (29, 0.2670232205374184), (30, 0.2670232205374184)]
# [(0, 0.5627826994238668), (25, 0.06852701102344375), (31, 0.4942556884004231), (32, 0.6590075845338975)]
# [(25, 0.04862458611152949), (33, 0.46761080869785787), (34, 0.3507081065233934), (35, 0.46761080869785787), (36, 0.46761080869785787), (37, 0.46761080869785787)]

# %% [markdown]
# ### Bigrams and Trigrams

# %%
# Create bigram and trigram models
bigram = gensim.models.Phrases(result, min_count=2, threshold=5)  # Detect bigrams
trigram = gensim.models.Phrases(bigram[result], min_count=2, threshold=5)  # Detect trigrams based on bigrams

# Apply the bigram and trigram models to the corpus
bigram_result = [bigram[doc] for doc in result]  # Get bigrams
trigram_result = [trigram[bigram[doc]] for doc in result]  # Get trigrams

# Print out the bigram and trigram results
print("Bigrams:", bigram_result)
print("Trigrams:", trigram_result)
# Out:
# Bigrams: [['exporter', 'businessman', 'import_product', 'exporter', 'short_term', 'dlrs', 'tariff', 'import', 'japanese', 'electronic', 'semiconductor', 'japanese', 'tariff', 'billion_dlrs', 'electronic', 'export', 'product', 'japanese', 'electronics', 'tariff', 'export', 'tariff', 'taiwan', 'businessman', 'taiwan', 'surplus', 'billion_dlrs', 'year', 'surplus', 'taiwan', 'billion_dlrs', 'tariff', 'import_product', 'exporter', 'south_korea', 'south_korea', 'export', 'year', 'south_korea', 'surplus', 'billion_dlrs', 'billion_dlrs', 'businessman', 'semiconductor', 'hong_kong', 'semiconductor', 'electronic', 'businessman', 'short_term', 'import', 'short_term', 'hong_kong', 'industry', 'import', 'hong_kong', 'year', 'hong_kong', 'export', 'industry', 'minister', 'export', 'export', 'japanese', 'year', 'minister', 'minister', 'industry'], ['china', 'pct', 'pct', 'china', 'china', 'say', 'say', 'pct', 'china', 'pct', 'say'], ['energy', 'demand', 'miti_energy', 'supply', 'demand', 'energy', 'demand', 'say', 'miti_energy', 'say', 'demand', 'miti_energy', 'supply', 'demand', 'natural', 'energy', 'say', 'say', 'miti_energy', 'supply', 'natural', 'energy', 'pct', 'pct', 'natural', 'pct'], ['quarter', 'billion_baht', 'quarter', 'billion', 'say', 'say', 'billion_baht', 'billion', 'quarter', 'say', 'quarter', 'billion_baht', 'billion'], ['indonesia', 'cpo', 'indonesia_palm', 'oil', 'cpo', 'harahap', 'cpo', 'say', 'harahap', 'say', 'indonesia_palm', 'oil', 'indonesia_palm', 'oil', 'palm_oil', 'harahap', 'say', 'cpo'], ['ban_nsw', 'port_nsw', 'ban_nsw', 'port', 'shipping', 'say', 'ban', 'port', 'say', 'port', 'port', 'say', 'nsw_port', 'nsw', 'shipping', 'say', 'port', 'port', 'say', 'say', 'shipping'], ['commodity', 'commodity', 'start', 'trade', 'commodity', 'nainggolan', 'trading', 'palm_oil', 'trading', 'palm_oil', 'palm_oil', 'trade', 'coffee_rubber', 'nainggolan', 'rubber', 'trading_coffee', 'rubber', 'coffee', 'trade', 'trading', 'rubber', 'trade', 'rubber', 'rubber', 'nainggolan', 'start', 'trading_coffee', 'rubber', 'start', 'trading', 'rubber', 'trading_coffee'], [], ['gold', 'wmc', 'say', 'gold', 'wmc', 'wmc', 'say', 'say', 'gold'], ['merger', 'ltd', 'merger', 'heiwa_sogo', 'financial', 'analyst', 'heiwa_sogo', 'komatsu', 'year', 'komatsu', 'merger', 'financial', 'analyst', 'pay', 'heiwa_sogo', 'merger', 'analyst', 'security_business', 'ltd', 'financial', 'security_business', 'pay', 'pct', 'time', 'business', 'komatsu', 'pay', 'time', 'year', 'komatsu', 'komatsu_security', 'business', 'security', 'komatsu', 'business', 'komatsu_security', 'security_business', 'securities', 'ltd', 'pct', 'komatsu_security', 'business', 'security', 'bank', 'bank', 'pct', 'komatsu', 'year', 'bank', 'business', 'analyst', 'time', 'merger', 'heiwa_sogo'], ['subroto', 'pact', 'extension', 'subroto', 'extension', 'sixth', 'ita', 'say', 'pact', 'say', 'pact', 'subroto', 'say', 'extension', 'ita', 'extension', 'sixth', 'say', 'sixth', 'ita', 'extension'], ['bundesbank_billion', 'mark_bundesbank', 'billion_mark', 'today', 'spokesman_say', 'bank', 'billion_mark', 'liquidity', 'today', 'billion_mark', 'market', 'today', 'bundesbank_billion', 'mark', 'market', 'today', 'bundesbank', 'spokesman_say', 'liquidity', 'bank', 'billion_mark', 'bundesbank_billion', 'mark_bundesbank', 'spokesman', 'billion_mark', 'billion', 'bank', 'liquidity', 'say', 'bundesbank', 'liquidity', 'market_market', 'market', 'bundesbank', 'say'], ['bond_corp', 'mining', 'bond_corp', 'mining', 'development', 'corp_mining', 'statement', 'say', 'copper', 'say', 'copper', 'company', 'say', 'copper', 'say', 'bond', 'company_gold', 'say', 'bond', 'mining', 'company_gold', 'say', 'development', 'development', 'company_gold', 'corp_statement', 'say', 'bond_corp', 'statement', 'say', 'development'], ['china_industrial', 'output', 'quarter', 'china_industrial', 'output', 'pct', 'quarter', 'say', 'say', 'pct', 'quarter', 'industrial_output', 'pct', 'quarter', 'say', 'china_industrial'], ['ministry', 'o ...
# Trigrams: [['exporter', 'businessman', 'import_product', 'exporter', 'short_term', 'dlrs', 'tariff', 'import', 'japanese', 'electronic', 'semiconductor', 'japanese', 'tariff', 'billion_dlrs', 'electronic', 'export', 'product', 'japanese', 'electronics', 'tariff', 'export', 'tariff', 'taiwan', 'businessman', 'taiwan', 'surplus', 'billion_dlrs', 'year', 'surplus', 'taiwan', 'billion_dlrs', 'tariff', 'import_product', 'exporter', 'south_korea', 'south_korea', 'export', 'year', 'south_korea', 'surplus', 'billion_dlrs_billion_dlrs', 'businessman', 'semiconductor', 'hong_kong', 'semiconductor', 'electronic', 'businessman', 'short_term', 'import', 'short_term', 'hong_kong', 'industry', 'import', 'hong_kong', 'year', 'hong_kong', 'export', 'industry', 'minister', 'export', 'export', 'japanese', 'year', 'minister', 'minister', 'industry'], ['china', 'pct', 'pct', 'china', 'china', 'say', 'say', 'pct', 'china', 'pct', 'say'], ['energy', 'demand', 'miti_energy_supply', 'demand', 'energy', 'demand', 'say', 'miti_energy', 'say', 'demand', 'miti_energy_supply', 'demand', 'natural', 'energy', 'say', 'say', 'miti_energy_supply', 'natural', 'energy', 'pct', 'pct', 'natural', 'pct'], ['quarter', 'billion_baht', 'quarter', 'billion', 'say', 'say', 'billion_baht', 'billion', 'quarter', 'say', 'quarter', 'billion_baht', 'billion'], ['indonesia', 'cpo', 'indonesia_palm_oil', 'cpo', 'harahap', 'cpo', 'say', 'harahap', 'say', 'indonesia_palm_oil', 'indonesia_palm_oil', 'palm_oil', 'harahap', 'say', 'cpo'], ['ban_nsw', 'port_nsw', 'ban_nsw', 'port', 'shipping', 'say', 'ban', 'port', 'say', 'port', 'port', 'say', 'nsw_port', 'nsw', 'shipping', 'say', 'port', 'port', 'say', 'say', 'shipping'], ['commodity', 'commodity', 'start', 'trade', 'commodity', 'nainggolan', 'trading', 'palm_oil', 'trading', 'palm_oil', 'palm_oil', 'trade', 'coffee_rubber', 'nainggolan', 'rubber', 'trading_coffee', 'rubber', 'coffee', 'trade', 'trading', 'rubber', 'trade', 'rubber', 'rubber', 'nainggolan', 'start', 'trading_coffee', 'rubber', 'start', 'trading', 'rubber', 'trading_coffee'], [], ['gold', 'wmc', 'say', 'gold', 'wmc', 'wmc', 'say', 'say', 'gold'], ['merger', 'ltd', 'merger', 'heiwa_sogo', 'financial', 'analyst', 'heiwa_sogo', 'komatsu', 'year', 'komatsu', 'merger', 'financial', 'analyst', 'pay', 'heiwa_sogo', 'merger', 'analyst', 'security_business', 'ltd', 'financial', 'security_business', 'pay', 'pct', 'time', 'business', 'komatsu', 'pay', 'time', 'year', 'komatsu', 'komatsu_security', 'business', 'security', 'komatsu', 'business', 'komatsu_security', 'security_business', 'securities', 'ltd', 'pct', 'komatsu_security', 'business', 'security', 'bank', 'bank', 'pct', 'komatsu', 'year', 'bank', 'business', 'analyst', 'time', 'merger', 'heiwa_sogo'], ['subroto', 'pact', 'extension', 'subroto', 'extension', 'sixth', 'ita', 'say', 'pact', 'say', 'pact', 'subroto', 'say', 'extension', 'ita', 'extension', 'sixth', 'say', 'sixth', 'ita', 'extension'], ['bundesbank_billion', 'mark_bundesbank', 'billion_mark', 'today', 'spokesman_say', 'bank', 'billion_mark', 'liquidity', 'today', 'billion_mark', 'market', 'today', 'bundesbank_billion', 'mark', 'market', 'today', 'bundesbank', 'spokesman_say', 'liquidity', 'bank', 'billion_mark', 'bundesbank_billion', 'mark_bundesbank', 'spokesman', 'billion_mark', 'billion', 'bank', 'liquidity', 'say', 'bundesbank', 'liquidity', 'market_market', 'market', 'bundesbank', 'say'], ['bond_corp', 'mining', 'bond_corp', 'mining', 'development', 'corp_mining', 'statement', 'say', 'copper', 'say', 'copper', 'company', 'say', 'copper', 'say', 'bond', 'company_gold', 'say', 'bond', 'mining', 'company_gold', 'say', 'development', 'development', 'company_gold', 'corp_statement', 'say', 'bond_corp', 'statement', 'say', 'development'], ['china_industrial', 'output', 'quarter', 'china_industrial', 'output', 'pct', 'quarter', 'say', 'say', 'pct', 'quarter', 'industrial_output', 'pct', 'quarter', 'say', 'china_industrial'], ['ministry', 'open', 'farm', 'trade ...

# %%
dictionary = corpora.Dictionary(trigram_result)
print(dictionary.token2id)
corpus = [dictionary.doc2bow(text) for text in trigram_result]
print(corpus)
# Out:
# {'billion': 0, 'businessman': 1, 'dlrs': 2, 'electronic': 3, 'electronics': 4, 'export': 5, 'exporter': 6, 'hong': 7, 'import': 8, 'industry': 9, 'japanese': 10, 'kong': 11, 'korea': 12, 'minister': 13, 'product': 14, 'semiconductor': 15, 'short': 16, 'south': 17, 'surplus': 18, 'taiwan': 19, 'tariff': 20, 'term': 21, 'year': 22, 'china': 23, 'pct': 24, 'say': 25, 'demand': 26, 'energy': 27, 'miti': 28, 'natural': 29, 'supply': 30, 'baht': 31, 'quarter': 32, 'cpo': 33, 'harahap': 34, 'indonesia': 35, 'oil': 36, 'palm': 37}
# [[(0, 5), (1, 4), (2, 6), (3, 3), (4, 1), (5, 6), (6, 3), (7, 4), (8, 5), (9, 3), (10, 4), (11, 4), (12, 3), (13, 3), (14, 3), (15, 3), (16, 3), (17, 3), (18, 3), (19, 3), (20, 5), (21, 3), (22, 4)], [(23, 4), (24, 4), (25, 3)], [(24, 3), (25, 4), (26, 5), (27, 8), (28, 4), (29, 3), (30, 3)], [(0, 6), (25, 3), (31, 3), (32, 4)], [(25, 3), (33, 4), (34, 3), (35, 4), (36, 4), (37, 4)]]

# %%
# TF-IDF
from gensim import models
tfidf = models.TfidfModel(corpus)
for document in tfidf[corpus]:
    print(document)
# Out:
# [(0, 0.30599503068105227), (1, 0.24479602454484184), (2, 0.06119900613621046), (3, 0.1835970184086314), (4, 0.06119900613621046), (5, 0.3671940368172628), (6, 0.1835970184086314), (7, 0.24479602454484184), (8, 0.30599503068105227), (9, 0.1835970184086314), (10, 0.24479602454484184), (11, 0.1835970184086314), (12, 0.1835970184086314), (13, 0.1835970184086314), (14, 0.1835970184086314), (15, 0.1835970184086314), (16, 0.1835970184086314), (17, 0.1835970184086314), (18, 0.30599503068105227), (19, 0.24479602454484184)]
# [(20, 0.8655034152183875), (21, 0.4927513833513657), (22, 0.08999951361325781)]
# [(21, 0.21480126240633127), (22, 0.06974717354477868), (23, 0.6288202410901308), (24, 0.5030561928721047), (25, 0.12576404821802617), (26, 0.37729214465407857), (27, 0.37729214465407857)]
# [(22, 0.09499183049472043), (28, 0.4567566557321679), (29, 0.4567566557321679), (30, 0.22837832786608395), (31, 0.22837832786608395), (32, 0.6851349835982519)]
# [(22, 0.06915746471498917), (33, 0.6650705042238236), (34, 0.4988028781678678), (35, 0.1662676260559559), (36, 0.4988028781678678), (37, 0.1662676260559559)]

# %% [markdown]
# ## Taggers

# %%
import plac
import random
from pathlib import Path
import spacy
from spacy.training import Example

# %%
TAG_MAP = {
    'N': 'NOUN',
    'V': 'VERB',
    'J':'ADJ',
    'NNS' : 'NOUN'
}

TRAIN_DATA = [
    ("I like green eggs", {'tags': ['N', 'V', 'J', 'NNS']}), 
    ("Eat blue ham", {'tags': ['V', 'J', 'N']}), 
]

# %%
def main(lang='en', output_dir=None, n_iter=3):

    nlp = spacy.blank(lang) #Créer un modèle spacy vide pour l'anglais
    tagger = nlp.add_pipe("tagger") #Créer un modèle (tagger) qui attribue des tags aux mots d'un texte 

    for item in TAG_MAP:
        tagger.add_label(item) #Ajouter des tags aux tagger

    optimizer = nlp.begin_training()
    for i in range(n_iter):
        random.shuffle(TRAIN_DATA)
        losses = {}
        for text, annotations in TRAIN_DATA:
            example = Example.from_dict(nlp.make_doc(text), annotations)
            nlp.update([example], sgd=optimizer, losses=losses)
        print(losses)

    test_text = "I love cats"
    doc = nlp(test_text)
    print('Tags', [(t.text, t.tag_, t.pos_) for t in doc])

# %%
main()
# Out:
# {'tagger': 5.233839750289917}
# {'tagger': 4.370360851287842}
# {'tagger': 2.9379818439483643}
# Tags [('I', 'N', ''), ('love', 'V', ''), ('cats', 'NNS', '')]

# %% [markdown]
# ## Ner Taggin

# %%
import plac
import random
from pathlib import Path
import spacy
# training data
TRAIN_DATA = [
('Who is Shaka Khan?', {
    'entities': [(7, 17, 'PERSON')]
}),
('I like London and Berlin.', {
    'entities': [(7, 13, 'LOC'), (18, 24, 'LOC')]
}),
 ('I am learning Python', {
    'entities': [(14, 20, 'TECH')]
})
]

# %%
def main(model=None, output_dir=None, n_iter=100):
    
    if model is not None:
        nlp = spacy.load(model)  # load existing spaCy model
        print("Loaded model '%s'" % model)
    else:
        nlp = spacy.blank('en')  # create blank Language class
        print("Created blank 'en' model")
        
        if 'ner' not in nlp.pipe_names:
            ner = nlp.add_pipe('ner', last=True)
    # otherwise, get it so we can add labels
        else:
            ner = nlp.get_pipe('ner')

    # add labels
    for _, annotations in TRAIN_DATA:
        for ent in annotations.get('entities'):
            ner.add_label(ent[2])
    
    # get names of other pipes to disable them during training 
    other_pipes = [pipe for pipe in nlp.pipe_names if pipe != 'ner']
    with nlp.disable_pipes(*other_pipes):  # only train NER
        optimizer = nlp.begin_training()
        
        for itn in range(n_iter):
            random.shuffle(TRAIN_DATA)
            losses = {}
            for text, annotations in TRAIN_DATA:
                example = Example.from_dict(nlp.make_doc(text), annotations)
                nlp.update(
                    [example],
                    drop=0.5, # dropout-make it harder to memorise data
                    sgd=optimizer, # callable to update weights
                    losses=losses)
            print(losses)
            
    # test the trained model
    doc = nlp('I love Python')
    print()
    print('Entities', [(ent.text, ent.label_) for ent in doc.ents])
    print('Tokens', [(t.text, t.ent_type_, t.ent_iob) for t in doc])

# %%
main()
# Out:
# Created blank 'en' model
# {'ner': 13.707800328731537}
# {'ner': 12.919663846492767}
# {'ner': 11.507942080497742}
# {'ner': 10.41474586725235}
# {'ner': 9.270761519670486}
# {'ner': 7.802250295877457}
# {'ner': 6.526705324649811}
# {'ner': 5.892342917621136}
# {'ner': 6.269278216175735}
# {'ner': 5.874239942058921}
# {'ner': 6.915091509465128}
# {'ner': 5.222462212201208}
# {'ner': 4.845556299958844}
# {'ner': 5.384911714587361}
# {'ner': 4.623987916682381}
# {'ner': 7.581715064850869}
# {'ner': 3.501235793111846}
# {'ner': 3.5995443491265178}
# {'ner': 4.172266533860238}
# {'ner': 3.0489110057242215}
# {'ner': 3.4836665840266505}
# {'ner': 3.081052483757958}
# {'ner': 3.0997456966488244}
# {'ner': 3.073208049734376}
# {'ner': 1.6782227643139862}
# {'ner': 4.133288230419396}
# {'ner': 2.541362160071003}
# {'ner': 0.8770357887357232}
# {'ner': 1.436662475178501}
# {'ner': 1.1867294459195326}
# {'ner': 1.8348952525510072}
# {'ner': 0.9213925234892738}
# {'ner': 1.2702341690707881}
# {'ner': 2.1776027171745396}
# {'ner': 0.4078910874332304}
# {'ner': 0.6864130095624286}
# {'ner': 1.844524342089695}
# {'ner': 1.5328188993965577}
# {'ner': 0.7817015529624955}
# {'ner': 0.6299875912803756}
# {'ner': 0.0015871207843678819}
# {'ner': 0.12139785476605153}
# {'ner': 0.008879777454878508}
# {'ner': 0.2162094168350719}
# {'ner': 0.017289904558462323}
# {'ner': 0.014306050062823312}
# {'ner': 0.0009612011613644243}
# {'ner': 3.298445184387495e-05}
# {'ner': 0.0013682070445437298}
# {'ner': 0.03717530315707417}
# {'ner': 0.0002632088829983168}
# {'ner': 0.0007104027287189133}
# {'ner': 9.901903218701377e-07}
# {'ner': 0.0008899770997497276}
# {'ner': 0.0017160644808086394}
# {'ner': 0.013852952757365864}
# {'ner': 0.022471555313597315}
# {'ner': 0.000876087487915726}
# {'ner': 0.0005630476694091976}
# {'ner': 0.00020371258018035042}
# {'ner': 0.00020192368033748607}
# {'ner': 0.0014997401394875897}
# {'ner': 0.0005791316347453289}
# {'ner': 0.0002507239527739194}
# {'ner': 0.00022537358654287383}
# {'ner': 3.772780943907175e-08}
# {'ner': 0.047879910751850226}
# {'ner': 7.140055536230062e-06}
# {'ner': 3.3151939367852264e-05}
# {'ner': 0.2627686010818958}
# {'ner': 2.9077695765049084e-08}
# {'ner': 4.170159314680698e-08}
# {'ner': 5.0849584258490276e-05}
# {'ner': 6.745617386917997e-06}
# {'ner': 9.752575909227634e-05}
# {'ner': 0.0003028166114288565}
# {'ner': 2.604862650944955e-06}
# {'ner': 8.768752434253054e-09}
# {'ner': 6.8858062529861365e-06}
# {'ner': 1.6171287452220877e-09}
# {'ner': 9.574721379032757e-09}
# {'ner': 2.929292818953902e-08}
# {'ner': 2.4074478785521714e-08}
# {'ner': 3.322239947467531e-09}
# {'ner': 2.4806203072186478e-09}
# {'ner': 8.688099497301498e-06}
# {'ner': 1.023841583259798e-07}
# {'ner': 4.88481811183669e-08}
# {'ner': 5.301958336685395e-07}
# {'ner': 1.8132509899370862e-06}
# {'ner': 5.638062635094584e-05}
# {'ner': 6.250005211519847e-07}
# {'ner': 3.1439005089826004e-07}
# {'ner': 9.202841102470627e-09}
# {'ner': 0.00036234914706458017}
# {'ner': 5.039862049668456e-07}
# {'ner': 0.00010587918138829075}
# {'ner': 7.073713109855256e-07}
# {'ner': 1.0181968294713431e-05}
# {'ner': 6.94029702076897e-08}
#
# Entities [('Python', 'TECH')]
# Tokens [('I', '', 2), ('love', '', 2), ('Python', 'TECH', 3)]

# %% [markdown]
# ## tp4

# %%
import spacy
from spacy.tokens import DocBin
from spacy.training.example import Example

# Load a blank spaCy model
nlp = spacy.blank("en")

# Add the "Quantity" label to the parser
if "parser" not in nlp.pipe_names:
    parser = nlp.add_pipe("parser")
else:
    parser = nlp.get_pipe("parser")
parser.add_label("Quantity")

# training data 
training_data = [
    ("Few people attended the meeting", {"heads": [1, 2, 2, 2, 2], "deps": ["Quantity", "nsubj", "ROOT", "det", "dobj"]}),
    ("We need many volunteers", {"heads": [1, 1, 1, 1], "deps": ["nsubj", "ROOT", "Quantity", "dobj"]}),
    ("Some books are more interesting than others", {"heads": [1, 2, 2, 3, 2, 5, 4], "deps": ["Quantity", "nsubj", "ROOT", "advmod", "acomp", "prep", "pobj"]}),
    ("She knows all her neighbors", {"heads": [1, 1, 4, 4, 1], "deps": ["nsubj", "ROOT", "Quantity", "poss", "dobj"]}),
    ("He read half the book", {"heads": [1, 1, 4, 4, 1], "deps": ["nsubj", "ROOT", "Quantity", "det", "dobj"]}),
    ("She read the whole book in one day", {"heads": [1, 1, 4, 4, 1, 4, 5, 1], "deps": ["nsubj", "ROOT", "det", "Quantity", "dobj", "prep", "nummod", "pobj"]}),
    ("I have enough time", {"heads": [1, 1, 1, 1], "deps": ["nsubj", "ROOT", "Quantity", "dobj"]}),
    ("There were numerous complaints about the noise", {"heads": [1, 1, 3, 1, 5, 3, 5], "deps": ["expl", "ROOT", "Quantity", "attr", "prep", "det", "pobj"]})
]

# Train the model
optimizer = nlp.begin_training()
for i in range(19):  
    for text, annotations in training_data:
        doc = nlp.make_doc(text)
        example = Example.from_dict(doc, {"heads": annotations["heads"], "deps": annotations["deps"]})
        nlp.update([example], sgd=optimizer)

# Test the model
test_text = ["Few places are this beautiful",
            "We have many plants at home",
            "Some people prefer to work in the evening",
            "She gave all her energy",             
            "He drank half the cup of water",            
            "She met with the whole team",
            "We have enough time to finish the task",
            "There are numerous doctors in the region"]
for text in test_text:
    doc = nlp(text)
    for token in doc:
        print(token.text, token.dep_, token.head.text)

    print()
# Out:
# Few Quantity places
# places dep are
# are ROOT are
# this dep beautiful
# beautiful dep are
#
# We dep have
# have ROOT have
# many Quantity have
# plants dep have
# at dep home
# home dep have
#
# Some Quantity people
# people dep prefer
# prefer ROOT prefer
# to dep work
# work dep prefer
# in dep work
# the dep in
# evening dep prefer
#
# She dep gave
# gave ROOT gave
# all Quantity energy
# her dep energy
# energy dep gave
#
# He dep drank
# drank ROOT drank
# half Quantity cup
# the dep cup
# cup dep drank
# of dep water
# water ROOT water
#
# She dep met
# met ROOT met
# with dep met
# the dep with
# whole Quantity team
# team dep with
#
# We dep have
# have ROOT have
# enough Quantity have
# time dep have
# to dep have
# finish dep the
# the dep to
# task dep the
#
# There dep are
# are ROOT are
# numerous Quantity doctors
# doctors dep are
# in dep doctors
# the dep in
# region dep in
